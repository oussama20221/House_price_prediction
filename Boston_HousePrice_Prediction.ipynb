# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/Boston Dataset.csv')
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
# Statistical description
df.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
#No null values is df
#chas column looks like it contains only 0/1 (Boolean)
#First column 'Unnamed' to drop from df

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
#506 lines in dataset
#15 columns
#No categorical columns (All numerical int/float)

# %%
df.drop('Unnamed: 0',axis=1 ,inplace=True)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
# No null values to fill
# No categorical columns to encode

# %%
#Let's take a look on the data distributions

# %%
fig, ax = plt.subplots(2, 7, figsize=(15,10))
index = 0
ax = ax.flatten()
for col in df.columns:
  sns.boxplot(y=col, data=df, ax=ax[index])
  index+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
fig, ax = plt.subplots(2,7, figsize=(15, 10))
index = 0
ax = ax.flatten()

for col in df.columns:
  sns.distplot(df[col], ax=ax[index])
  index+=1
# Out:
# <ipython-input-84-bd106308cc8f>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-84-bd106308cc8f>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-84-bd106308cc8f>:6: UserWarning:
#
# ...

# %%
#We can observe right skewed and left skewed graphs for 'crim', 'zn', 'tax', and 'black'.

# %%
#Min Max Normalization
ToNorm = ['crim', 'zn', 'tax', 'black']
for col in ToNorm:
  Max=max(df[col])
  Min=min(df[col])
  df[col]=(df[col]-Min)/(Max-Min)

# %%
fig, ax = plt.subplots(2, 7, figsize=(15,10))
index = 0
ax = ax.flatten()

for col in df.columns:
  sns.distplot(df[col], ax=ax[index])
  index+=1
# Out:
# <ipython-input-87-2417cd12f0f8>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-87-2417cd12f0f8>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-87-2417cd12f0f8>:6: UserWarning:
#
# ...

# %%
#Standardization Z-score normalization

# %%
from sklearn import preprocessing

stand = preprocessing.StandardScaler()

# %%
ToStand = ['crim', 'zn', 'tax', 'black']
df[ToStand] = (stand.fit_transform(df[ToStand]))

# %%
df[ToStand].head()
# Out:
#        crim        zn       tax     black
# 0 -0.419782  0.284830 -0.666608  0.441052
# 1 -0.417339 -0.487722 -0.987329  0.441052
# 2 -0.417342 -0.487722 -0.987329  0.396427
# 3 -0.416750 -0.487722 -1.106115  0.416163
# 4 -0.412482 -0.487722 -1.106115  0.441052

# %%
fig, ax = plt.subplots(2,7, figsize=(15,10))
index = 0
ax = ax.flatten()

for col in df.columns:
  sns.distplot(df[col], ax=ax[index])
  index += 1
# Out:
# <ipython-input-92-eded67447f40>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-92-eded67447f40>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col], ax=ax[index])
# <ipython-input-92-eded67447f40>:6: UserWarning:
#
# ...

# %%
corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#Correlation between the target variable and correlated features

# %%
sns.regplot(y=df['medv'],x=df['lstat'],order=1) #We can see they are negatively correlated
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
sns.regplot(y=df['medv'], x=df['rm']) #Positevly correlated
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %%
#Split data for training and testing

# %%
X = df.drop(columns=['medv','rad'])
y = df['medv']

# %%
# Model Training

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error

# %%
def train(model, X, y):
  X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

  model.fit(X_train, y_train)

  pred = model.predict(X_test)

  cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)

  print(f"MSE : {mean_squared_error(pred, y_test)}")
  print(f"cv : {cv_score}")

  print(f"cv_score : {np.abs(np.mean(cv_score))}")

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()

# %%
train(LR, X, y)
# Out:
# MSE : 23.871005067364944
# cv : [-12.73033975 -25.01453235 -34.21189837 -84.68277882 -21.26728177]
# cv_score : 35.58136621076916

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# MSE : 19.891417322834645
# cv : [-12.41245098 -34.25366337 -25.94277228 -54.72346535 -65.01663366]
# cv_score : 38.4697971267715
# <Axes: title={'center': 'Feature Importance'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# MSE : 9.753261062992134
# cv : [ -7.95583661 -13.67956907 -20.27541069 -45.57896073 -16.81232589]
# cv_score : 20.86042059879634
# <Axes: title={'center': 'Feature Importance'}>

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# MSE : 10.987650055118113
# cv : [ -9.38299425 -16.31871618 -12.10104817 -41.6601373  -19.3873774 ]
# cv_score : 19.770054658901177
# <Axes: title={'center': 'Feature Importance'}>

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# MSE : 11.681987314123807
# cv : [ -8.49357816 -33.87289329 -25.97394917 -43.39455293 -22.76662476]
# cv_score : 26.900319661354462
# <Axes: title={'center': 'Feature Importance'}>
